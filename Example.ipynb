# %%
# %matplotlib notebook

# %%
import pandas as pd
import numpy as np
import rampwf as rw

# %% [markdown]
# # Loading the dataset

# %%
from problem import get_train_data, get_test_data

# %%
X, y = get_train_data()

# %%
X.head()
# Out:
#                      year  month  day  hour  DEWP  TEMP    PRES cbwd    Iws  \
# 2010-01-01 00:00:00  2010      1    1     0   -21 -11.0  1021.0   NW   1.79
# 2010-01-01 01:00:00  2010      1    1     1   -21 -12.0  1020.0   NW   4.92
# 2010-01-01 02:00:00  2010      1    1     2   -21 -11.0  1019.0   NW   6.71
# 2010-01-01 03:00:00  2010      1    1     3   -21 -14.0  1019.0   NW   9.84
# 2010-01-01 04:00:00  2010      1    1     4   -20 -12.0  1018.0   NW  12.97
#
#                      Is  Ir
# 2010-01-01 00:00:00   0   0
# 2010-01-01 01:00:00   0   0
# 2010-01-01 02:00:00   0   0
# 2010-01-01 03:00:00   0   0
# 2010-01-01 04:00:00   0   0

# %% [markdown]
# # Some stats

# %%
y.name
# Out:
# 'pm2.5'

# %%
y.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Running the test

# %%
# !ramp_test_submission
# Out:
# Testing Predicting the pollution of Bejing with the weather
# Reading train and test files from ./data ...
# Reading cv ...
# Training submissions/starting_kit ...
# CV fold 0
# Traceback (most recent call last):
#   File "/home/nicolas/anaconda3/envs/china-pollution/bin/ramp_test_submission", line 11, in <module>
#     sys.exit(ramp_test_submission())
#   File "/home/nicolas/anaconda3/envs/china-pollution/lib/python3.7/site-packages/rampwf/utils/command_line.py", line 104, in ramp_test_submission
#     retrain=retrain)
#   File "/home/nicolas/anaconda3/envs/china-pollution/lib/python3.7/site-packages/rampwf/utils/testing.py", line 123, in assert_submission
#     fold, ramp_data_dir)
#   File "/home/nicolas/anaconda3/envs/china-pollution/lib/python3.7/site-packages/rampwf/utils/submission.py", line 188, in run_submission_on_cv_fold
#     y_true=y_train[train_is])
# ...
